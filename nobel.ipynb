# %%
import pandas as pd

# %%
data_wo_uni = pd.read_html("https://en.wikipedia.org/wiki/List_of_Nobel_laureates")

# %%
data_w_uni = pd.read_html("https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_university_affiliation", match = "Nobel laureates by affiliation")

# %%
data_wo_uni[0]
# Out:
#      Year                                           Physics  \
# 0    1901                                   Wilhelm Röntgen
# 1    1902                    Hendrik Lorentz; Pieter Zeeman
# 2    1903        Henri Becquerel; Pierre Curie; Marie Curie
# 3    1904                                     Lord Rayleigh
# 4    1905                                    Philipp Lenard
# ..    ...                                               ...
# 119  2020    Roger Penrose; Reinhard Genzel; Andrea M. Ghez
# 120  2021  Giorgio Parisi; Klaus Hasselmann; Syukuro Manabe
# 121  2022       Alain Aspect; John Clauser; Anton Zeilinger
# 122  2023   Pierre Agostini; Ferenc Krausz; Anne L'Huillier
# 123  Year                                           Physics
#
#                                              Chemistry  \
# 0                         Jacobus Henricus van 't Hoff
# 1                                         Emil Fischer
# 2                                     Svante Arrhenius
# ...

# %%
len(data_w_uni)
# Out:
# 1

# %%
data_w_uni[0]
# Out:
#                     Laureate              Discipline  Year of award  \
# 0           Alexei Abrikosov                 Physics           2003
# 1               Edgar Adrian  Physiology or Medicine           1932
# 2            Pierre Agostini                 Physics           2023
# 3                 Peter Agre               Chemistry           2003
# 4              Isamu Akasaki                 Physics           2014
# ..                       ...                     ...            ...
# 806            Frits Zernike                 Physics           1953
# 807             Ahmed Zewail               Chemistry           1999
# 808             Karl Ziegler               Chemistry           1963
# 809      Rolf M. Zinkernagel  Physiology or Medicine           1996
# 810  Richard Adolf Zsigmondy               Chemistry           1925
#
#                                 Affiliation
# 0               Argonne National Laboratory
# 1                   University of Cambridge
# ...

# %%
data_w_uni[0].to_csv("nobel_laureates_with_affiliation.csv")

# %%
data_wo_uni[0].to_csv("nobel_laureates_with_affiliation.csv")

# %%
pd.DataFrame(data_w_uni[0].Affiliation.value_counts())
# Out:
#                                                Affiliation
# Harvard University                                      31
# Massachusetts Institute of Technology                   24
# Stanford University                                     22
# University of California, Berkeley                      21
# California Institute of Technology                      20
# ...                                                    ...
# National Research Council Canada                         1
# University of Innsbruck                                  1
# Ghent University                                         1
# Czechoslovak Academy of Sciences                         1
# China Academy of Traditional Chinese Medicine            1
#
# [311 rows x 1 columns]
